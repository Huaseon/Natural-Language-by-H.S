# %%
import pandas as pd

# %%
def get_acc(dir: list[str]) -> list[float]:
    if dir:
        df = pd.read_csv(f'{dir[0]}/preds_test.csv')
        return {dir[0]: 1 - (df.iloc[:, 2::3].to_numpy() - df.iloc[:, ::3].to_numpy()).__abs__().mean(),  **get_acc(dir[1:])}
    return {}

# %%
get_acc(['3-2-10', '3-2-13', '3-2-15', '3-2-20', '3-2-25', 'output/experiment-v1', 'output/experiment-v2'])
# Out:
# {'3-2-10': 0.9299015132384079,
#  '3-2-13': 0.929225914038265,
#  '3-2-15': 0.9300169216424353,
#  '3-2-20': 0.928378794010522,
#  '3-2-25': 0.9278932073536497,
#  'output/experiment-v1': 0.9278932073536497,
#  'output/experiment-v2': 0.9226965454008609}

# %%
[z+"/"+x+"/"+y for x, y, z in zip(
"0.8357/0.8664/0.8919/0.9067/0.9121/0.9126/0.9119".split('/'),
"0.8487/0.8676/0.8753/0.8823/0.8873/0.8876/0.8837".split('/'),
"15/15/15/15/12/4/3".split('/'),
)
]
# Out:
# ['15/0.8357/0.8487',
#  '15/0.8664/0.8676',
#  '15/0.8919/0.8753',
#  '15/0.9067/0.8823',
#  '12/0.9121/0.8873',
#  '4/0.9126/0.8876',
#  '3/0.9119/0.8837']

# %%
[z+"/"+x+"/"+y for x, y, z in zip(
"0.8390/0.8700/0.8956/0.9093/0.9098/0.9108/0.9098".split('/'),
"0.8508/0.8696/0.8769/0.8798/0.8907/0.8857/0.8818".split('/'),
"20/20/20/20/9/6/4".split('/'),
)
]
# Out:
# ['20/0.8390/0.8508',
#  '20/0.8700/0.8696',
#  '20/0.8956/0.8769',
#  '20/0.9093/0.8798',
#  '9/0.9098/0.8907',
#  '6/0.9108/0.8857',
#  '4/0.9098/0.8818']

# %%
[z+"/"+x+"/"+y for x, y, z in zip(
"0.8423/0.8710/0.8926/0.9052/0.9056/0.9033/0.9026".split('/'),
"0.8555/0.8709/0.8758/0.8885/0.8861/0.8897/0.8890".split('/'),
"25/25/25/25/5/7/5".split('/'),
)
]
# Out:
# ['25/0.8423/0.8555',
#  '25/0.8710/0.8709',
#  '25/0.8926/0.8758',
#  '25/0.9052/0.8885',
#  '5/0.9056/0.8861',
#  '7/0.9033/0.8897',
#  '5/0.9026/0.8890']

# %%
[z+"/"+x+"/"+y for x, y, z in zip(
"0.8348/0.8580/0.8794/0.8902/0.8893/0.8899/0.8892".split('/'),
"0.8477/0.8691/0.8702/0.8809/0.8817/0.8805/0.8785".split('/'),
"30/30/30/28/5/5/6".split('/'),
)
]
# Out:
# ['30/0.8348/0.8477',
#  '30/0.8580/0.8691',
#  '30/0.8794/0.8702',
#  '28/0.8902/0.8809',
#  '5/0.8893/0.8817',
#  '5/0.8899/0.8805',
#  '6/0.8892/0.8785']

# %%
[z+"/"+x+"/"+y for x, y, z in zip(
"0.8348/0.8580/0.8794/0.8902/0.8893/0.8899/0.8892".split('/'),
"0.8477/0.8691/0.8702/0.8809/0.8817/0.8805/0.8785".split('/'),
"30/30/30/28/5/5/6".split('/'),
)
]
# Out:
# ['30/0.8348/0.8477',
#  '30/0.8580/0.8691',
#  '30/0.8794/0.8702',
#  '28/0.8902/0.8809',
#  '5/0.8893/0.8817',
#  '5/0.8899/0.8805',
#  '6/0.8892/0.8785']

# %%
"0.8357/0.8664/0.8919/0.9067/0.9121/0.9126/0.9119"
"0.8487/0.8676/0.8753/0.8823/0.8873/0.8876/0.8837"
"15/15/15/15/12/4/3"

"0.8390/0.8700/0.8956/0.9093/0.9098/0.9108/0.9098"
"0.8508/0.8696/0.8769/0.8798/0.8907/0.8857/0.8818"
"20/20/20/20/9/6/4"

"0.8423/0.8710/0.8926/0.9052/0.9056/0.9033/0.9026"
"0.8555/0.8709/0.8758/0.8885/0.8861/0.8897/0.8890"
"25/25/25/25/5/7/5"

"0.8348/0.8580/0.8794/0.8902/0.8893/0.8899/0.8892"
"0.8477/0.8691/0.8702/0.8809/0.8817/0.8805/0.8785"
"30/30/30/28/5/5/6"
